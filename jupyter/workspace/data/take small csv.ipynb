# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('steam_reviews.csv')

# Take the first 1000 rows
df_subset = df.head(1000)

# Save to a new CSV file
df_subset.to_csv('1000_steam_reviews.csv', index=False)

print("✅ Saved the first 1000 rows to output.csv")

# %%
# Take the first 10000 rows
df_subset = df.head(10000)

# Save to a new CSV file
df_subset.to_csv('10000_steam_reviews.csv', index=False)

print("✅ Saved the first 10000 rows to 10000_steam_reviews.csv")
